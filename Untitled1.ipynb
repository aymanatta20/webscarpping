# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = "https://wuzzuf.net/search/jobs/?q=ai%20engineer&a=hpb"

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
website = requests.get(url).text

# %%
website
# Out:
# '<!DOCTYPE html>\n<html lang="en" translate="no">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">\n    <meta http-equiv="expires" content="Thu Dec 08 2022 18:30:44 GMT+0200" />\n\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate">\n    <meta name="googlebot" content="notranslate">\n    <title data-react-helmet="true">50 ai engineer Jobs in Egypt – Discover Job Details Now!</title>\n\n<meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" name="description" content="Explore 50 ai engineer Jobs in Egypt. Discover exciting opportunities with a leading recruitment company. Start your job search today!"/><meta data-react-helmet="true" name="keywords" content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employm
# ...

# %%
mywebsite = BeautifulSoup(website , "html")

# %%
mywebsite
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">50 ai engineer Jobs in Egypt – Discover Job Details Now!</title>
# ...

# %%
job = mywebsite .find("div", class_="css-1gatmva e1v1l3u10")

# %%
print(job.prettify())
# Out:
# <div class="css-1gatmva e1v1l3u10">
#  <style data-emotion="css pkv5jc">
#   .css-pkv5jc{position:relative;min-height:60px;}
#  </style>
#  <div class="css-pkv5jc">
#   <a rel="noreferrer" target="_blank">
#    <style data-emotion="css 17095x3">
#     .css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}
#    </style>
#   </a>
#   <style data-emotion="css laomuu">
#    .css-laomuu{padding-right:60px;}
#   </style>
#   <div class="css-laomuu">
#    <style data-emotion="css m604qf">
#     .css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}
#    </style>
#    <h2 class="css-m604qf">
#     <style data-emotion="css o171kl">
#      .css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}
#     </style>
# ...

# %%
jobtitle = job.find("h2" , class_="css-m604qf")

# %%
jobtitle.a.text
# Out:
# 'AI Technical Team Lead'

# %%
company = job.find("a" , class_ = "css-17s97q8").text

# %%
companylication = job.find("span" , class_ = "css-5wys0k").text

# %%
jobtype = job.find("span",class_="css-1ve4b75 eoyjyou0").text

# %%
jobs = mywebsite.find_all("div", class_="css-1gatmva e1v1l3u10") 
len(jobs)
# Out:
# 15

# %%
for job in jobs : 
    jobtitle = job.find("h2" , class_="css-m604qf").a.text
    company = job.find("a" , class_ = "css-17s97q8").text
    companylocation = job.find("span" , class_ = "css-5wys0k").text
    jobtype = job.find("span",class_="css-1ve4b75 eoyjyou0").text
    print(jobtitle,company,companylication,jobtype)
# Out:
# AI Technical Team Lead Confidential - Cairo, Egypt  Full Time
# Artificial Intelligence( AI )Business Development Confidential - Cairo, Egypt  Full Time
# Product Manager - EPM/AI/ML Azdan Business Analytics - Cairo, Egypt  Full Time
# Senior AI Engineer Lumin - Cairo, Egypt  Full Time
# AI Engineer The Osiris Labs  - Cairo, Egypt  Full Time
# Technical Project Manager Sprints.ai - Cairo, Egypt  Full Time
# Data Science Instructor EpsilonAI - Cairo, Egypt  Full Time
# Python Artisan Developer coto - Cairo, Egypt  Full Time
# AI Engineer UAE General Civil Aviation Authority (GCAA) - Cairo, Egypt  Full Time
# Site Reliability Engineer Citylogix ME - Cairo, Egypt  Full Time
# B2B Telesales Account Manager Confidential - Cairo, Egypt  Full Time
# Senior Python Developer Nile Bits, LLC - Cairo, Egypt  Full Time
# Senior Architect Designer Lecon - Cairo, Egypt  Full Time
# Senior JavaFX Developer Wakeb Data - Cairo, Egypt  Full Time
# ...

# %%
for i in range(4) : 
    url = f"https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20engineer&start={i}"
    website = requests.get(url).text
    mywebsite = BeautifulSoup(website, "html")
    jobs = mywebsite.find_all("div", class_="css-1gatmva e1v1l3u10")
    
    for job in jobs : 
        jobtitle = job.find("h2" , class_="css-m604qf").a.text
        company = job.find("a" , class_ = "css-17s97q8").text
        companylocation = job.find("span" , class_ = "css-5wys0k").text
        jobtype = job.find("span",class_="css-1ve4b75 eoyjyou0").text
        print(jobtitle,company,companylication,jobtype)
# Out:
# AI Technical Team Lead Confidential - Cairo, Egypt  Full Time
# Artificial Intelligence( AI )Business Development Confidential - Cairo, Egypt  Full Time
# Product Manager - EPM/AI/ML Azdan Business Analytics - Cairo, Egypt  Full Time
# Senior AI Engineer Lumin - Cairo, Egypt  Full Time
# AI Engineer The Osiris Labs  - Cairo, Egypt  Full Time
# Technical Project Manager Sprints.ai - Cairo, Egypt  Full Time
# Data Science Instructor EpsilonAI - Cairo, Egypt  Full Time
# Python Artisan Developer coto - Cairo, Egypt  Full Time
# AI Engineer UAE General Civil Aviation Authority (GCAA) - Cairo, Egypt  Full Time
# Site Reliability Engineer Citylogix ME - Cairo, Egypt  Full Time
# B2B Telesales Account Manager Confidential - Cairo, Egypt  Full Time
# Senior Python Developer Nile Bits, LLC - Cairo, Egypt  Full Time
# Senior Architect Designer Lecon - Cairo, Egypt  Full Time
# Senior JavaFX Developer Wakeb Data - Cairo, Egypt  Full Time
# ...

# %%
import csv # comma seperated value
csvfile = open("Elmon.csv" , "w" , encoding ="utf-8")
writer = csv.writer(csvfile)
writer .writerow(["jobtitle, company , companylocation , jobtype"])
# Out:
# 49

# %%
for i in range(4) : 
    url = f"https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20engineer&start={i}"
    website = requests.get(url).text
    mywebsite = BeautifulSoup(website, "html")
    for job in jobs : 
        jobtitle = job.find("h2" , class_="css-m604qf").a.text
        company = job.find("a" , class_ = "css-17s97q8").text
        companylication = job.find("span" , class_ = "css-5wys0k").text
        jobtype = job.find("span",class_="css-1ve4b75 eoyjyou0").text
        writer.writerow([jobtitle,company,jobtype , companylication])

# %%
csvfile.close()
